# %%
import matplotlib.pyplot as plt 
import cv2 as cv
from PIL import Image

# %%
image = Image.open('figures/fig1.png')
image.show()
image = Image.open('figures/fig2.png')
image.show()
image = Image.open('figures/fig_3.png')
image.show()
image = Image.open('figures/fig_4.png')
image.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# #### 2.2. как зависит поведение методов от числа обусловленности, от начальной точки, от стратегии выбора длины шага?
#
# Из рисунка выше видно, что как будто бы чем ниже обусловленность матрицы тем быстрее сходится алгоритм для Armijo и Wolfe, для Constant шага алгоритм достигает лимита по итерациям=1000. Касательно траектории видно, что с уменьшением числа обусловленности, она стала более плавной. Для разных линий уровня константный шаг не сошелся, достигнув предела по итерациям.

# %%
image = Image.open('figures/Armijo_iter_vs_k_n.png')
image.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# #### 2.3. Как полученные результаты согласуются с теорией, т.е. с теоретическими оценками на число итераций GD?
#
# Из рисунка выше видно, что с увеличением размерности функции у кривой зависимости числа итераций от числа обсуловленности значение дисперсии уменьшается и кривая становится похожей на гиперболическую зависимость, то есть кривые по итерациям становятся кучнее (так должно быть). До k=300 зависимость линейная. Также видно, что чем ниже размерность матрицы тем больше итераций требуется до того, как алгоритм сойдется, либо будет достигнут лимит по итерациям.
